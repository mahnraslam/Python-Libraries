# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
youth_per  = [29,19,21,27,20,19,17,25,28]
countries = ['Pakistan','England' ,'Australia','India','America','France','Japan','Turkey','Nigeria']
sns.scatterplot(x = countries , y = youth_per )
plt.show()

# %%
 
#View the first five rows of the DataFrame df. Is it tidy? Why or why not?

# Possible answers
 
# No, because a single column contains different types of information
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')
sns.countplot(x = 'Maxpulse',data = df)
plt.show()

# %%
d = pd.read_excel('titanic3.xls ')
sns.scatterplot(x='age' , y = 'sex',hue = 'sex',palette = {'female' : 'c','male':'black'} ,data =  d,hue_order=['male','female'])
#sns.countplot(x = 'age' , hue= 'sex',data = d  )
plt.show()

# %%
import numpy as np
import random
array = np.zeros((2,2) , dtype = int)
array[1][1] = 7
places  = np.argwhere(array == 0)
print(random.choice(places), array.size)
# Out:
# [1 0] 4
